# %%
# %pip install sympy
# %pip install numpy
# %pip install matplotlib
# %pip install scipy
# Out:
# Requirement already satisfied: sympy in /workspace/.venv/lib/python3.13/site-packages (1.14.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /workspace/.venv/lib/python3.13/site-packages (from sympy) (1.3.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in /workspace/.venv/lib/python3.13/site-packages (2.4.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in /workspace/.venv/lib/python3.13/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /workspace/.venv/lib/python3.13/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /workspace/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scipy in /workspace/.venv/lib/python3.13/site-packages (1.16.3)
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /workspace/.venv/lib/python3.13/site-packages (from scipy) (2.4.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy import symbols, diff, simplify, init_printing
init_printing()

# Curve v1 equations
x, y, D, A = symbols("x y D A")
k = A*x*y/(D/2)**2
f = x*y + k*(x+y)*D - (D/2)**2 - k*D**2

df_dx = diff(f, x)
df_dy = diff(f, y)
dy_dx = -df_dx / df_dy

display(f)
print(simplify(dy_dx))
# Out:
#                               2
#            4⋅A⋅x⋅y⋅(x + y)   D
# -4⋅A⋅x⋅y + ─────────────── - ── + x⋅y
#                   D          4
# y*(4*A*D - 8*A*x - 4*A*y - D)/(x*(-4*A*D + 4*A*x + 8*A*y + D))

# %%
# Curve v2 equations
x, y, D, A, g = symbols("x y D A g")
k0 = x*y/(D/2)**2
k = A*k0*g**2/(g+1-k0)**2
f = x*y + k*D*(x+y) - (D/2)**2 - k*D**2

df_dx = diff(f, x)
df_dy = diff(f, y)
dy_dx = -df_dx / df_dy

display(f)
print(simplify(dy_dx))
# Out:
#           2               2                2
#      4⋅A⋅g ⋅x⋅y      4⋅A⋅g ⋅x⋅y⋅(x + y)   D
# - ──────────────── + ────────────────── - ── + x⋅y
#                  2                    2   4
#   ⎛        4⋅x⋅y⎞      ⎛        4⋅x⋅y⎞
#   ⎜g + 1 - ─────⎟    D⋅⎜g + 1 - ─────⎟
#   ⎜          2  ⎟      ⎜          2  ⎟
#   ⎝         D   ⎠      ⎝         D   ⎠
# y*(32*A*D**3*g**2*x*y*(D - x - y) + 4*A*D**3*g**2*(D**2*(g + 1) - 4*x*y)*(D - 2*x - y) - (D**2*(g + 1) - 4*x*y)**3)/(x*(32*A*D**3*g**2*x*y*(-D + x + y) + 4*A*D**3*g**2*(D**2*(g + 1) - 4*x*y)*(-D + x + 2*y) + (D**2*(g + 1) - 4*x*y)**3))

# %%
D = 200
A = 5
g = 0.1

xs = np.linspace(0, 400, 1000)
ys = np.linspace(0, 400, 1000)

x, y = np.meshgrid(xs, ys)

# Constant product
f_cp = x*y - (D/2)**2
# Curve v1
k = x*y/(D/2)**2
f_curve_v1 = x*y + A*k*(x+y)*D - (D/2)**2 - A*k*D**2
# Curve v2
k0 = x*y/(D/2)**2
k = A*k0*g**2/(g+1-k0)**2
f_curve_v2 = x*y + k*D*(x+y) - (D/2)**2 - k*D**2

plt.figure(figsize=(8, 8)) 
plt.axis('equal')

plt.contour(x, y, f_cp, levels=[0], colors='blue')
plt.contour(x, y, f_curve_v1, levels=[0], colors='orange')
plt.contour(x, y, f_curve_v2, levels=[0], colors='green')

plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import fsolve

import warnings
warnings.simplefilter("ignore", category=Warning)

D = 20
A = 5
g = 0.05

def f_cp(y, x, D):
    return x*y - (D/2)**2

def dy_dx_cp(x, y):
    return -y/x

def f_curve_v1(y, x, A, D):
    k = A*x*y/(D/2)**2
    return x*y + k*D*(x+y) - (D/2)**2 - k*D**2
    
def dy_dx_curve_v1(x, y):
    return y*(4*A*D - 8*A*x - 4*A*y - D)/(x*(-4*A*D + 4*A*x + 8*A*y + D))

def f_curve_v2(y, x, A, D, g):
    k0 = x*y/(D/2)**2
    k = A*k0*g**2/(g+1-k0)**2
    return x*y + k*D*(x+y) - (D/2)**2 - k*D**2
    
def dy_dx_curve_v2(x, y):
    return y*(32*A*D**3*g**2*x*y*(D - x - y) + 4*A*D**3*g**2*(D**2*(g + 1) - 4*x*y)*(D - 2*x - y) - (D**2*(g + 1) - 4*x*y)**3)/(x*(32*A*D**3*g**2*x*y*(-D + x + y) + 4*A*D**3*g**2*(D**2*(g + 1) - 4*x*y)*(-D + x + 2*y) + (D**2*(g + 1) - 4*x*y)**3))

xs = np.linspace(1, 40, 100)

ys_cp = [fsolve(f_cp, D, args=(x, D))[0] for x in xs]
ps_cp = [-dy_dx_cp(x, y) for x, y in zip(xs, ys_cp)]

ys_curve_v1 = [fsolve(f_curve_v1, D, args=(x, A, D))[0] for x in xs]
ps_curve_v1 = [-dy_dx_curve_v1(x, y) for x, y in zip(xs, ys_curve_v1)]

ys_curve_v2 = [fsolve(f_curve_v2, (D/2)**2, args=(x, A, D, g))[0] for x in xs]
ps_curve_v2 = [-dy_dx_curve_v2(x, y) for x, y in zip(xs, ys_curve_v2)]

plt.figure(figsize=(8, 8)) 
plt.axis('equal')

plt.axhline(1, color = "grey")
plt.plot(xs, ps_cp)
plt.plot(xs, ps_curve_v1)
plt.plot(xs, ps_curve_v2)
plt.legend([
    "constant sum",
    "constant product", 
    "curve v1", 
    "curve v2"
])

plt.xlim(2, 18)
plt.ylim(0, 10)
plt.grid(True)
plt.show()
# Out:
# Ignoring fixed y limits to fulfill fixed data aspect with adjustable data limits.
